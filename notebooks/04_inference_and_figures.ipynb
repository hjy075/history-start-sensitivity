# %% [markdown]
# # 04_inference_and_figures
#
# Runs the corrected bootstrap inference, paper-facing tables, and manuscript figures. The version-controlled logic lives under `src/inference/`.

# %%
from pathlib import Path

# Run from a cloned repository.
STEP_DIR = Path("../src/inference")
for step in sorted(STEP_DIR.glob("part_*.py")):
    print(f"\n=== {step.name} ===")
    exec(compile(step.read_text(), str(step), "exec"), globals())
