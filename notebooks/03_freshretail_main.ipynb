# %% [markdown]
# # 03_freshretail_main
#
# Thin runner notebook. The version-controlled experiment logic lives under `src/`.

# %%
from pathlib import Path

# Run from a cloned repository.
STEP_DIR = Path("../src/freshretail")
for step in sorted(STEP_DIR.glob("part_*.py")):
    print(f"\n=== {step.name} ===")
    exec(compile(step.read_text(), str(step), "exec"), globals())
